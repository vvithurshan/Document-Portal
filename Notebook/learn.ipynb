# %%
from pathlib import Path

# %%
pdf_path = "/Users/uw-user/Documents/AI-2025/LLMOps/Document-Portal/data/document_analysis/sample.pdf"

class DummyFile:
    def __init__(self, file_path):
        self.name = Path(file_path).name
        self._file_path = file_path
        print(self._file_path)
        print(self.name)
        
    def getbuffer(self):
        return open(self._file_path, "rb").read()
    
dummy_pdf = DummyFile(pdf_path)
# Out:
# /Users/uw-user/Documents/AI-2025/LLMOps/Document-Portal/data/document_analysis/sample.pdf
# sample.pdf

# %%
import os
p = os.path.join('folder','subfolder','main.py')

# %%
os.path.basename(p)
# Out:
# 'main.py'
